# %% [markdown]
# # Prediction using Decision Tree  Algorithm
# Task No: 02
# Level: Intermediate Level
# By: Kalki.R

# %%
#importing libraries

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree
from sklearn import tree

# %%
#import dataset

data = load_iris()
df = pd.DataFrame(data.data, columns = data.feature_names)
df['target'] = data.target

# %%
#Reading dataset

df = pd.read_csv('C:/Users/Dell/OneDrive/Desktop/iris.csv')

# %%
#checking for null values

df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Showing first 5 values

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#Showing only target data (Dependent Variable)

print(df['target'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int32

# %%
#splitting data

fc = [x for x in df.columns if x!="target"]
x= df[fc]
y= df["target"]
X_train, X_test, Y_train, Y_test = train_test_split(x,y, random_state = 90, test_size = 0.20)

# %%
# Display of data

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %%
#building Desicion tree model

model1 = DecisionTreeClassifier()

# %%
model1.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred = model1.predict(X_test)

# %%
data2 = pd.DataFrame({"Actual":Y_test,"Predicted":Y_pred})
data2.head()
# Out:
#      Actual  Predicted
# 90        1          1
# 16        0          0
# 15        0          0
# 111       2          2
# 136       2          2

# %%
#Testing the accuracy of model prediction

accuracy_score(Y_test,Y_pred)
# Out:
# 0.9666666666666667

# %%
#Plotting

f_n = ["Sepal length", "Sepal width", "Petal length", "Petal width"]
c_n = ["Setosa", "Versicolor", "Virginica"]
plot_tree(model1,feature_names = f_n, class_names = c_n,filled = True)
# Out:
# [Text(181.35000000000002, 201.90857142857143, 'Petal width <= 0.8\ngini = 0.665\nsamples = 120\nvalue = [41, 43, 36]\nclass = Versicolor'),
#  Text(153.45000000000002, 170.84571428571428, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]\nclass = Setosa'),
#  Text(209.25000000000003, 170.84571428571428, 'Petal width <= 1.75\ngini = 0.496\nsamples = 79\nvalue = [0, 43, 36]\nclass = Versicolor'),
#  Text(139.5, 139.78285714285715, 'Petal length <= 5.35\ngini = 0.159\nsamples = 46\nvalue = [0, 42, 4]\nclass = Versicolor'),
#  Text(111.60000000000001, 108.72, 'Petal width <= 1.65\ngini = 0.087\nsamples = 44\nvalue = [0, 42, 2]\nclass = Versicolor'),
#  Text(55.800000000000004, 77.65714285714284, 'Petal length <= 4.95\ngini = 0.046\nsamples = 42\nvalue = [0, 41, 1]\nclass = Versicolor'),
#  Text(27.900000000000002, 46.59428571428572, 'gini = 0.0\nsamples = 40\nvalue = [0, 40, 0]\nclass = Versicolor'),
#  Text(83.7, 46.59428571428572, 'Sepal width <= 2.45\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = Versicolor'),
#  Text(55.800000000000004, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Virginica'),
#  Text(111.60000000000001, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(167.4, 77.65714285714284, 'Sepal length <= 5.8\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = Versicolor'),
#  Text(139.5, 46.59428571428572, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Virginica'),
#  Text(195.3, 46.59428571428572, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(167.4, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = Virginica'),
#  Text(279.0, 139.78285714285715, 'Petal length <= 4.85\ngini = 0.059\nsamples = 33\nvalue = [0, 1, 32]\nclass = Virginica'),
#  Text(251.10000000000002, 108.72, 'Sepal length <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = Virginica'),
#  Text(223.20000000000002, 77.65714285714284, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(279.0, 77.65714285714284, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = Virginica'),
#  Text(306.90000000000003, 108.72, 'gini = 0.0\nsamples = 30\nvalue = [0, 0, 30]\nclass = Virginica')]

# %%
modelx= DecisionTreeClassifier().fit(x,y)

# %%
plt.figure(figsize = (10,13))
tree = tree.plot_tree(modelx, feature_names = f_n, class_names = c_n, filled = True)
