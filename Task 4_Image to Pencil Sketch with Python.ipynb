# %% [markdown]
# # Level: Beginner level
# Task : 04
# Task Name: Image to pencil sketch with Python
# By: Kalki R

# %%
#Importing Moduls

import cv2

# %%
image = cv2.imread("C:/Users/Dell/OneDrive/Documents/baby.jpg")

# %%
cv2.imshow("Baby", image)
cv2.waitKey(0)
# Out:
# -1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.title('Original Image')
plt.axis('off')
plt.imshow(img_rgb)

# %%
gray_img=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
gray_img
# Out:
# array([[ 68,  82,  75, ...,  74,  72,  71],
#        [ 76,  77,  79, ..., 104,  99,  94],
#        [ 68,  68,  76, ..., 121, 115, 108],
#        ...,
#        [ 28,  29,  30, ..., 119, 118, 116],
#        [ 30,  30,  30, ..., 122, 120, 118],
#        [ 32,  32,  32, ..., 124, 123, 120]], dtype=uint8)

# %%
plt.title('Gray scale image')
plt.axis('off')
plt.imshow(gray_img)

# %%
inverted_img=255-gray_img
plt.title('Inverted image')
plt.axis('off')
plt.imshow(inverted_img)

# %%
blurred=cv2.GaussianBlur(inverted_img, (21, 21), 0)
plt.title('Blured image')
plt.axis('off')
plt.imshow(blurred)

# %%
inverted_blurred=255-blurred
pencil_sketch=cv2.divide(gray_img, inverted_blurred, scale=256.0)
cv2.imshow("Sketch",pencil_sketch)
cv2.waitKey(0)
# Out:
# -1
